# %%
import pandas as pd

# %%
#folder = r'U:\Greens tech\Advanced python\books_data'
import pandas as pd
folder = r'C:\Users\hp\Downloads'
books = pd.read_csv(f'{folder}/books.csv') # read the csv
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4012\3376304666.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(f'{folder}/books.csv') # read the csv

# %%
books
# Out:
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
books.head() # by default it will print 5 rows
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# ...

# %%
books.tail()
# Out:
#               ISBN                                         Book-Title  \
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                 Book-Author Year-Of-Publication  \
# 271355       Paula Danziger                1988
# 271356           Teri Sloat                1991
# 271357     Christine Wicker                2004
# 271358                Plato                1996
# 271359  Christopher  Biffle                2000
#
#                                                Publisher  \
# 271355                   Random House Childrens Pub (Mm)
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# ...

# %%
books.tail(10)
# Out:
#               ISBN                                         Book-Title  \
# 271350  0762412119  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 271351  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 271352  1845170423                                  Cocktail Classics
# 271353  014002803X                                  Anti Death League
# 271354  0449906736      Flashpoints: Promise and Peril in a New World
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 271350         Allan Armitage                2002
# 271351  Allen M., Ph.D. Young                2001
# ...

# %%
cols=['ISBN','Book-Title','Book-Author','Year-Of-Publication','Publisher']
folder = r'C:\Users\hp\Downloads'
books1 = pd.read_csv(f'{folder}/books.csv', usecols=cols) # read the csv 
books1
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4012\3290574332.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books1 = pd.read_csv(f'{folder}/books.csv', usecols=cols) # read the csv
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
#loc - print all the data within the particular range, it will accept the string 
#iloc - it will follow indexing format, it won't accept string

# %%
books1.loc[30:40]
# Out:
#           ISBN                                       Book-Title  \
# 30  0375759778                                 Prague : A Novel
# 31  0425163091                                  Chocolate Jesus
# 32  3404921038                             Wie Barney es sieht.
# 33  3442353866  Der Fluch der Kaiserin. Ein Richter- Di- Roman.
# 34  3442410665                                Sturmzeit. Roman.
# 35  3442446937                               Tage der Unschuld.
# 36  0375406328                                      Lying Awake
# 37  0446310786                            To Kill a Mockingbird
# 38  0449005615                   Seabiscuit: An American Legend
# 39  0060168013                                   Pigs in Heaven
# 40  038078243X                 Miss Zukas and the Raven's Dance
#
#                 Book-Author Year-Of-Publication                      Publisher
# 30          ARTHUR PHILLIPS                2003  Random House Trade Paperbacks
# ...

# %%
#slicing[start:  stop(n-1): step]
books1.iloc[30:40]
# Out:
#           ISBN                                       Book-Title  \
# 30  0375759778                                 Prague : A Novel
# 31  0425163091                                  Chocolate Jesus
# 32  3404921038                             Wie Barney es sieht.
# 33  3442353866  Der Fluch der Kaiserin. Ein Richter- Di- Roman.
# 34  3442410665                                Sturmzeit. Roman.
# 35  3442446937                               Tage der Unschuld.
# 36  0375406328                                      Lying Awake
# 37  0446310786                            To Kill a Mockingbird
# 38  0449005615                   Seabiscuit: An American Legend
# 39  0060168013                                   Pigs in Heaven
#
#                 Book-Author Year-Of-Publication                      Publisher
# 30          ARTHUR PHILLIPS                2003  Random House Trade Paperbacks
# 31        Stephan Jaramillo                1998       Berkley Publishing Group
# ...

# %%
books1.loc[:10,('Publisher','ISBN')]
# Out:
#                      Publisher        ISBN
# 0      Oxford University Press  0195153448
# 1        HarperFlamingo Canada  0002005018
# 2              HarperPerennial  0060973129
# 3         Farrar Straus Giroux  0374157065
# 4   W. W. Norton &amp; Company  0393045218
# 5             Putnam Pub Group  0399135782
# 6     Berkley Publishing Group  0425176428
# 7                   Audioworks  0671870432
# 8                 Random House  0679425608
# 9                     Scribner  074322678X
# 10             Emblem Editions  0771074670

# %%
books1.iloc[:10,('Publisher','ISBN')]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 books1.iloc[:10,('Publisher','ISBN')]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
#    1593 def _getitem_tuple(self, tup: tuple):
# -> 1594     tup = self._validate_tuple_indexer(tup)
#    1595     with suppress(IndexingError):
#    1596         return self._getitem_lowerdim(tup)
#
# ...

# %%
books1.iloc[:10,:3]
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author
# 0    Mark P. O. Morford
# 1  Richard Bruce Wright
# 2          Carlo D'Este
# 3      Gina Bari Kolata
# 4       E. J. W. Barber
# 5               Amy Tan
# 6         Robert Cowley
# 7           Scott Turow
# ...

# %%
books1.loc[:10,['ISBN']]
# Out:
#           ISBN
# 0   0195153448
# 1   0002005018
# 2   0060973129
# 3   0374157065
# 4   0393045218
# 5   0399135782
# 6   0425176428
# 7   0671870432
# 8   0679425608
# 9   074322678X
# 10  0771074670

# %%
books1.iloc[:10,-2:]
# Out:
#   Year-Of-Publication                   Publisher
# 0                2002     Oxford University Press
# 1                2001       HarperFlamingo Canada
# 2                1991             HarperPerennial
# 3                1999        Farrar Straus Giroux
# 4                1999  W. W. Norton &amp; Company
# 5                1991            Putnam Pub Group
# 6                2000    Berkley Publishing Group
# 7                1993                  Audioworks
# 8                1996                Random House
# 9                2002                    Scribner

# %%
books1.iloc[:10,:1]
# Out:
#          ISBN
# 0  0195153448
# 1  0002005018
# 2  0060973129
# 3  0374157065
# 4  0393045218
# 5  0399135782
# 6  0425176428
# 7  0671870432
# 8  0679425608
# 9  074322678X

# %%
books1.iloc[:10:5]
# Out:
#          ISBN              Book-Title         Book-Author Year-Of-Publication  \
# 0  0195153448     Classical Mythology  Mark P. O. Morford                2002
# 5  0399135782  The Kitchen God's Wife             Amy Tan                1991
#
#                  Publisher
# 0  Oxford University Press
# 5         Putnam Pub Group

# %%
books1.iloc[:10,:5]
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author Year-Of-Publication                   Publisher
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# ...

# %%
## String functions
# split()
# contains()
# replace()
# upper()
#lower()

# %%
books1.shape
# Out:
# (271360, 5)

# %%
EDA ( Exploratory data Analysis) - 
Data cleanup - missing dta check, duplicate, outliers
normalization

hyperparameter -

# %% [markdown]
# # Missing data check

# %%
#books1.isna().sum()
books1.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# dtype: int64

# %%
# HAndle the missing data
#dropna - 
#fill - 0,1, mean, median, , bfill (Backward fill), ffill( forward fill)
mode - when column in the form of catagorical

# %%
books1.dropna(inplace=True)

# %%
books1.shape
# Out:
# (271356, 5)

# %%
books1.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# dtype: int64

# %%
modeval=books1['Book-Author'].mode()
modeval
# Out:
# 0    Agatha Christie
# Name: Book-Author, dtype: object

# %%
books1['Book-Author'].fillna(value=modeval,inplace=True)

# %%
books1.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# dtype: int64

# %% [markdown]
# # Duplicate

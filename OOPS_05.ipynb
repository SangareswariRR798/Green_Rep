# %% [markdown]
# Key OOP Concepts
# Class and Object:
# A class is a blueprint for objects, and an object is an instance of a class.
#
# Encapsulation:
# Hides the internal state of objects and requires all interaction to be performed through methods.
#
# Inheritance:
# Allows a class to inherit the properties and methods of another class.
#
# Polymorphism:
# Allows methods in different classes to have the same name but behave differently.
#
# Abstraction:
# Hides implementation details and shows only the essential features.

# %%
Class car
{
No_of_seat=4
N_of_wheel=4
    Air_bags_cout=2

}
car_BMW=car   # Object1 Creation
print(car_BMW.No_of_seat)


car_Swift=car  #  Object 2 creation
car_Swift.air_bags_count=3
print(car_Swift.air_bags_count)

# %%
# Step 1: Define a class
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder  # Public attribute
        self.__balance = balance  # Private attribute (Encapsulation)

    def deposit(self, amount):
        """Deposits money into the account."""
        if amount > 0:
            self.__balance += amount
            print(f"{amount} deposited. New balance: {self.__balance}")
        else:
            print("Invalid deposit amount!")

    def withdraw(self, amount):
        """Withdraws money from the account."""
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"{amount} withdrawn. New balance: {self.__balance}")
        else:
            print("Insufficient funds or invalid amount!")

    def get_balance(self):
        """Access the private balance attribute."""
        return self.__balance

# Step 2: Inherit and extend functionality
class SavingsAccount(BankAccount):
    def __init__(self, account_holder, balance=0, interest_rate=0.02):
        super().__init__(account_holder, balance)
        self.interest_rate = interest_rate

    def add_interest(self):
        """Adds interest to the balance."""
        interest = self.get_balance() * self.interest_rate
        self.deposit(interest)
        print(f"Interest of {interest} added.")

# Step 3: Polymorphism example
def print_account_info(account):
    """Polymorphic function that works with any account type."""
    print(f"Account holder: {account.account_holder}")
    print(f"Balance: {account.get_balance()}")

# Step 4: Test the code
if __name__ == "__main__":
    # Create objects
    john_account = BankAccount("John Doe", 100)
    jane_account = SavingsAccount("Jane Doe", 200)

    # Deposit and withdraw
    john_account.deposit(50)
    john_account.withdraw(30)

    # Savings account with interest
    jane_account.add_interest()

    # Polymorphic behavior
    print_account_info(john_account)
    print_account_info(jane_account)

# %%
# Abstract Base Class   - Hides implementation details and shows only the essential features.
# Abstract Base Class   - 
class Vehicle(ABC):
    @abstractmethod
    def start(self):
        pass

# Concrete Class: Car
class Car(Vehicle):
    def start(self):
        return "Car is starting."

# Concrete Class: Bike
class Bike(Vehicle):
    def start(self):
        return "Bike is starting."

# Using the abstract base class
if __name__ == "__main__":
    car = Car()
    bike = Bike()

    print(car.start())  # Output: Car is starting.
    print(bike.start())  # Output: Bike is starting.
